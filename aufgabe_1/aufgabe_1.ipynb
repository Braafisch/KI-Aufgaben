# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
fig = plt.figure()
ax =fig.add_subplot(projection='3d')
x_1 = np.arange(-10000, 100000, 10.)
x_2 = np.arange(-10000, 100000, 10.)

x_1, x_2 = np.meshgrid(x_1, x_2)

x_3 = (x_1 - 1)**2 - 2*x_1*x_1 + 2 * x_2**2 + 1
ax.plot_surface(x_1,x_2,x_3)

plt.show()
