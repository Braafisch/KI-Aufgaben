# %% [markdown]
# <a href="https://colab.research.google.com/github/Braafisch/KI-Aufgaben/blob/main/aufgabe_1/aufgabe_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure()
ax =fig.add_subplot(projection='3d')
x_1 = np.arange(-5, 5, 0.25)
x_2 = np.arange(-5, 5, 0.25)

x_1, x_2 = np.meshgrid(x_1, x_2)

x_3 = (x_1 - 1.)**2 - 2.*x_1*x_2 + 2.*x_2**2 + 1.
ax.plot_surface(x_1,x_2,x_3)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

x_3_x_1 = 2 * (x_1 - 1.)**2 - 2 * x_2
x_3_x_2 = -2 * x_1 + 4 * x_2
ax.plot_surface(x_1,x_2,x_3_x_1)
ax.plot_surface(x_1,x_2,x_3_x_2)
plt.show()

# %%
N = 10
s = 0.5 # strength of noise
x = np.linspace(0, 1, N)
e = np.random.normal(0, s, N)

y = np.sin(2*np.pi*x) + e
plt.scatter(x,y)

# for plotting
xx = np.linspace(0,1, 100)
plt.plot(xx, np.sin(2*np.pi*xx))

# %%
np.set_printoptions(suppress=True)
np.set_printoptions(precision=2)

N = 10
s = 0.5 # strength of noise
x = np.linspace(0, 1, N)
e = np.random.normal(0, s, N)

y = np.sin(2*np.pi*x)
plt.scatter(x,y)

p_hat = np.polyfit(x,y,6)
xx = np.linspace(0,1,100)
plt.plot(xx,np.polyval(p_hat,xx),label='no noise')

y=y+e
plt.scatter(x,y)
p_hat_2 = np.polyfit(x,y,6)
plt.plot(xx,np.polyval(p_hat_2,xx),label='with noise')
plt.legend();

# %%
N = 10
s = 0.5

L2 = [((np.polyfit(x,y,k))**2).sum() for k in range(1,N)]

plt.plot(range(1,N),L2)
plt.yscale('log')
plt.xlabel('degree')
plt.ylabel('$L_2$ norm');
